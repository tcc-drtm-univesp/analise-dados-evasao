# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", None)
dtypes = {
    'Ano de Ingresso': int,      # String
    'Ano de Referência': int,     # Inteiro
}
df = pd.read_excel("indicadores_trajetoria_educacao_superior_2017_2021.xlsx", dtype=dtypes)
df
# Out:
#         Código da Instituição                   Nome da Instituição  \
# 0                           1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# 1                           1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# 2                           1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# 3                           1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# 4                           1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# ...                       ...                                   ...
# 154470                  25352  Universidade Federal de Rondonópolis
# 154471                  25352  Universidade Federal de Rondonópolis
# 154472                  25352  Universidade Federal de Rondonópolis
# 154473                  25352  Universidade Federal de Rondonópolis
# 154474                  25352  Universidade Federal de Rondonópolis
#
#         Categoria Administrativa  Organização Acadêmica  \
# 0                              1                      1
# ...

# %%
def DesistenciaMediaGrandeAreaporAno(dfa, ano):
    """
    Função para calcular a média de desistência por Grande Área do CINE Brasil.
    Os parâmetros são o dataframe dfa e o ano desejado em inteiros.
    Por exemplo, para o primeiro ano de curso chamar DesistenciaMediaGrandeAreaporAno(df, 1)
    """
    #Filtra o df pelo ano
    dfa = dfa[dfa['Ano de Ingresso']==dfa['Ano de Referência'] - (ano-1)]
    
    #Imprime informações do df filtrado
    print(dfa.info())
    
    #Agrupa a desistência por Grande Área e imprime
    media_por_grande_area_ano = dfa.groupby('Nome da Grande Área do Curso segundo a classificação CINE BRASIL')['Taxa de Desistência Anual - TADA'].mean()
    print(media_por_grande_area_ano)
    
    #Exibe gráfico
    media_por_grande_area_ano.plot(kind='bar')
    plt.xlabel('Nome da Grande Área do Curso segundo a classificação CINE BRASIL')
    plt.ylabel('Taxa de Desistência Anual - TDAN')
    title = 'TDAN Média por Grande Área no ano ' + str(ano)
    plt.title(title)

# %%
DesistenciaMediaGrandeAreaporAno(df, ano = 1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 0 to 154470
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
DesistenciaMediaGrandeAreaporAno(df, ano = 2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 1 to 154471
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
DesistenciaMediaGrandeAreaporAno(df, ano = 3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 2 to 154472
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
DesistenciaMediaGrandeAreaporAno(df, ano = 4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 3 to 154473
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
DesistenciaMediaGrandeAreaporAno(df, ano = 5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 4 to 154474
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
#Esse arquivo contempla apenas 5 anos de acompanhamento
#DesistenciaMediaGrandeAreaporAno(df, ano = 6)

# %%
def DesistenciaMediaGrandeAreaConsideraPandemia(dfa, pandemia):
    """
    Função para calcular a média de desistência por Grande Área do CINE Brasil.
    Os parâmetros são o dataframe dfa e se deseja considerar anos com ou sem pandemia
    Por exemplo, para anos "sem" pandemia chamar DesistenciaMediaGrandeAreaConsideraPandemia(dfa, "não")
    Por exemplo, para anos "com" pandemia chamar DesistenciaMediaGrandeAreaConsideraPandemia(dfa, "sim")
    """
    
    if pandemia == "não":
        #Filtra apenas anos sem pandemia
        dfa_sem_pandemia = dfa[(dfa["Ano de Referência"] != 2020) & (dfa["Ano de Referência"] != 2021) ]
        print(dfa_sem_pandemia.info())
        #Agrupa por Grande Área CINE
        media_por_grande_area_sem_pandemia = dfa_sem_pandemia.groupby('Nome da Grande Área do Curso segundo a classificação CINE BRASIL')['Taxa de Desistência Anual - TADA'].mean()
        
        #Imprime média por Grande Área
        print(media_por_grande_area_sem_pandemia)
        
        #Exibe gráfico
        media_por_grande_area_sem_pandemia.plot(kind='bar')
        plt.xlabel('Nome da Grande Área do Curso segundo a classificação CINE BRASIL')
        plt.ylabel('Taxa de Desistência Anual - TDAN')
        plt.title('TDAN Média por Grande Área em anos sem pandemia')
        
    if pandemia == "sim":
        #Filtra apenas anos com pandemia
        dfa_com_pandemia = dfa[(dfa["Ano de Referência"] == 2020) | (dfa["Ano de Referência"] == 2021)]
        print(dfa_com_pandemia.info())
        
        #Agrupa por Grande Área CINE
        media_por_grande_area_com_pandemia = dfa_com_pandemia.groupby('Nome da Grande Área do Curso segundo a classificação CINE BRASIL')['Taxa de Desistência Anual - TADA'].mean()
        
        #Exibe gráfico
        print(media_por_grande_area_com_pandemia)
        media_por_grande_area_com_pandemia.plot(kind='bar')
        plt.xlabel('Nome da Grande Área do Curso segundo a classificação CINE BRASIL')
        plt.ylabel('Taxa de Desistência Anual - TDAN')
        plt.title('TDAN Média por Grande Área em anos com pandemia')

# %%
DesistenciaMediaGrandeAreaConsideraPandemia(df, pandemia = "não")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92685 entries, 0 to 154472
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               92685 non-null  int64
#  1   Nome da Instituição                                                 92685 non-null  object
#  2   Categoria Administrativa                                            92685 non-null  int64
#  3   Organização Acadêmica                                               92685 non-null  int64
#  4   Código do Curso de Graduação                                        92685 non-null  int64
#  5   Nome do Curso de Graduação                                          92685 non-null  object
#  6   Código da Região Geográfica do Curso                                86997 non-null  float64
# ...

# %%
DesistenciaMediaGrandeAreaConsideraPandemia(df, pandemia = "sim")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61790 entries, 3 to 154474
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               61790 non-null  int64
#  1   Nome da Instituição                                                 61790 non-null  object
#  2   Categoria Administrativa                                            61790 non-null  int64
#  3   Organização Acadêmica                                               61790 non-null  int64
#  4   Código do Curso de Graduação                                        61790 non-null  int64
#  5   Nome do Curso de Graduação                                          61790 non-null  object
#  6   Código da Região Geográfica do Curso                                57998 non-null  float64
# ...

# %%
def DesistenciaMediaModalidadedeEnsinoporAno(dfa, ano):
    """
    Função para calcular a média de desistência por Modalidade de Ensino.
    Os parâmetros são o dataframe dfa e o ano desejado em inteiros.
    Por exemplo, para o primeiro ano de curso chamar DesistenciaMediaModalidadedeEnsinoporAno(df, 1)
    """
    #Filtra o df pelo ano
    dfa = dfa[dfa['Ano de Ingresso']==dfa['Ano de Referência'] - (ano-1)]
    
    #Imprime informações do df filtrado
    print(dfa.info())
    
    #Agrupa a desistência por Grande Área e imprime
    media_por_modalidade_ano = dfa.groupby('Modalidade de Ensino')['Taxa de Desistência Anual - TADA'].mean()
    print(media_por_modalidade_ano)
    
    #Exibe gráfico
    media_por_modalidade_ano.plot(kind='bar')
    plt.xlabel('Modalidade de ensino: 1 - Presencial, 2 - EAD')
    plt.ylabel('Taxa de Desistência Anual - TDAN')
    title = 'TDAN Média por Modalidade de Ensino no ano ' + str(ano)
    plt.title(title)

# %%
DesistenciaMediaModalidadedeEnsinoporAno(df, ano = 1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 0 to 154470
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
DesistenciaMediaModalidadedeEnsinoporAno(df, ano = 2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 1 to 154471
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
DesistenciaMediaModalidadedeEnsinoporAno(df, ano = 3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 2 to 154472
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
DesistenciaMediaModalidadedeEnsinoporAno(df, ano = 4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 3 to 154473
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
DesistenciaMediaModalidadedeEnsinoporAno(df, ano = 5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30895 entries, 4 to 154474
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               30895 non-null  int64
#  1   Nome da Instituição                                                 30895 non-null  object
#  2   Categoria Administrativa                                            30895 non-null  int64
#  3   Organização Acadêmica                                               30895 non-null  int64
#  4   Código do Curso de Graduação                                        30895 non-null  int64
#  5   Nome do Curso de Graduação                                          30895 non-null  object
#  6   Código da Região Geográfica do Curso                                28999 non-null  float64
# ...

# %%
def DesistenciaModalidadedeEnsinoConsideraPandemia(dfa, pandemia):
    """
    Função para calcular a média de desistência por Modalidade de Ensino.
    Os parâmetros são o dataframe dfa e se deseja considerar anos com ou sem pandemia
    Por exemplo, para anos "sem" pandemia chamar DesistenciaModalidadedeEnsinoConsideraPandemia(dfa, "não")
    Por exemplo, para anos "com" pandemia chamar DesistenciaModalidadedeEnsinoConsideraPandemia(dfa, "sim")
    """
    
    if pandemia == "não":
        #Filtra apenas anos sem pandemia
        dfa_sem_pandemia = dfa[(dfa["Ano de Referência"] != 2020) & (dfa["Ano de Referência"] != 2021) ]
        print(dfa_sem_pandemia.info())
        #Agrupa por Grande Área CINE
        media_por_modalidade_sem_pandemia = dfa_sem_pandemia.groupby('Modalidade de Ensino')['Taxa de Desistência Anual - TADA'].mean()
        
        #Imprime média por Grande Área
        print(media_por_modalidade_sem_pandemia)
        
        #Exibe gráfico
        media_por_modalidade_sem_pandemia.plot(kind='bar')
        plt.xlabel('Modalidade de ensino: 1 - Presencial, 2 - EAD')
        plt.ylabel('Taxa de Desistência Anual - TDAN')
        plt.title('TDAN Média por Modalidade de Ensino em anos sem pandemia')
        
    if pandemia == "sim":
        #Filtra apenas anos com pandemia
        dfa_com_pandemia = dfa[(dfa["Ano de Referência"] == 2020) | (dfa["Ano de Referência"] == 2021)]
        print(dfa_com_pandemia.info())
        
        #Agrupa por Grande Área CINE
        media_por_modalidade_com_pandemia = dfa_com_pandemia.groupby('Modalidade de Ensino')['Taxa de Desistência Anual - TADA'].mean()
        
        #Exibe gráfico
        print(media_por_modalidade_com_pandemia)
        media_por_modalidade_com_pandemia.plot(kind='bar')
        plt.xlabel('Modalidade de ensino: 1 - Presencial, 2 - EAD')
        plt.ylabel('Taxa de Desistência Anual - TDAN')
        plt.title('TDAN Média por Modalidade de Ensino em anos com pandemia')

# %%
DesistenciaModalidadedeEnsinoConsideraPandemia(df, pandemia = "não")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92685 entries, 0 to 154472
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               92685 non-null  int64
#  1   Nome da Instituição                                                 92685 non-null  object
#  2   Categoria Administrativa                                            92685 non-null  int64
#  3   Organização Acadêmica                                               92685 non-null  int64
#  4   Código do Curso de Graduação                                        92685 non-null  int64
#  5   Nome do Curso de Graduação                                          92685 non-null  object
#  6   Código da Região Geográfica do Curso                                86997 non-null  float64
# ...

# %%
DesistenciaModalidadedeEnsinoConsideraPandemia(df, pandemia = "sim")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61790 entries, 3 to 154474
# Data columns (total 31 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Código da Instituição                                               61790 non-null  int64
#  1   Nome da Instituição                                                 61790 non-null  object
#  2   Categoria Administrativa                                            61790 non-null  int64
#  3   Organização Acadêmica                                               61790 non-null  int64
#  4   Código do Curso de Graduação                                        61790 non-null  int64
#  5   Nome do Curso de Graduação                                          61790 non-null  object
#  6   Código da Região Geográfica do Curso                                57998 non-null  float64
# ...

# %%
df_para_histograma = df[df['Ano de Referência'] == 2021]
df_para_histograma
# Out:
#         Código da Instituição                   Nome da Instituição  \
# 4                           1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# 9                           1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# 14                          1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# 19                          1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# 24                          1   UNIVERSIDADE FEDERAL DE MATO GROSSO
# ...                       ...                                   ...
# 154454                  25352  Universidade Federal de Rondonópolis
# 154459                  25352  Universidade Federal de Rondonópolis
# 154464                  25352  Universidade Federal de Rondonópolis
# 154469                  25352  Universidade Federal de Rondonópolis
# 154474                  25352  Universidade Federal de Rondonópolis
#
#         Categoria Administrativa  Organização Acadêmica  \
# 4                              1                      1
# ...

# %%
print('Média: ', df_para_histograma['Taxa de Desistência Acumulada - TDA'].mean())
print('Médiana: ', df_para_histograma['Taxa de Desistência Acumulada - TDA'].median())
print('Desvio Padrão: ', df_para_histograma['Taxa de Desistência Acumulada - TDA'].std())
# Out:
# Média:  52.77355233926261
# Médiana:  52.94117647
# Desvio Padrão:  23.311518682527065

# %%
# Defina os limites das bins em intervalos de 1%
bins = [i for i in range(0 , 101 , 5)]  # Isso cria uma lista de 0 a 100

# Crie o histograma usando o método hist do pandas
df_para_histograma['Taxa de Desistência Acumulada - TDA'].plot(kind='hist', bins=bins, edgecolor='k')

# Personalize o gráfico
plt.title('Histograma Taxa de Desistência Acumulada - TDA em Intervalos de 5%')
plt.xlabel('Taxa de Desistência Acumulada')
plt.ylabel('Contagem')
plt.xticks(range(0, 101, 10))  # Personalize os rótulos do eixo x
plt.grid(True)

# Exiba o gráfico
plt.show()
